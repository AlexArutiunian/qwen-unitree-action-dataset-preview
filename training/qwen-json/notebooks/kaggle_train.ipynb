# %% [markdown]
# # Local QLoRA Robot JSON Project
#
# This notebook was refactored into a normal Python project. Use the terminal commands in `README.md`.

# %%
# Compact training from the project root:
# !python -m src.train --config configs/train_compact_4096.yaml

# %%
# Evaluation example:
# !python -m src.evaluate --config configs/train_compact_4096.yaml --adapter outputs/best_adapter --split reserved

# %%
# Plot generation example:
# !python -m src.plot_training --run-dir outputs/compact_4096
